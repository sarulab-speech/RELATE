# %%
import pandas as pd
df = pd.read_csv("scores/REL.csv")
df
# Out:
#                            wavname  \
# 0        /audiocaps/train/8215.wav
# 1           /tango/test/102816.wav
# 2       /audioldm2/train/98806.wav
# 3       /audiocaps/test/106912.wav
# 4        /audioldm/test/106912.wav
# ...                            ...
# 28765  /audioldm2/train/101407.wav
# 28766   /audiocaps/test/103379.wav
# 28767   /audioldm2/train/50099.wav
# 28768       /tango/train/50099.wav
# 28769       /tango/train/26958.wav
#
#                                                     text  score  listener_id  \
# 0      A muffled steam engine running as a crowd of p...      1            0
# 1      A group of people screaming and laughing as fi...      8            0
# 2             Wind noises with a siren in the background      9            0
# 3      An aircraft engine humming followed by plastic...      9            0
# 4      An aircraft engine humming followed by plastic...      3            0
# ...

# %%
df = df[df["in RELATE dataset"]!="excluded"]
df
# Out:
#                            wavname  \
# 1           /tango/test/102816.wav
# 2       /audioldm2/train/98806.wav
# 3       /audiocaps/test/106912.wav
# 4        /audioldm/test/106912.wav
# 5       /audiocaps/train/67949.wav
# ...                            ...
# 28763       /tango/train/86290.wav
# 28765  /audioldm2/train/101407.wav
# 28767   /audioldm2/train/50099.wav
# 28768       /tango/train/50099.wav
# 28769       /tango/train/26958.wav
#
#                                                     text  score  listener_id  \
# 1      A group of people screaming and laughing as fi...      8            0
# 2             Wind noises with a siren in the background      9            0
# 3      An aircraft engine humming followed by plastic...      9            0
# 4      An aircraft engine humming followed by plastic...      3            0
# 5                Water falls into a pool and frogs croak     10            0
# ...
